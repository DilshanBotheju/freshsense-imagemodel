# %% [markdown]
# <a href="https://colab.research.google.com/github/SiyumiJayawardhane/freshsense-imagemodel/blob/dev/bananaclassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATASET_PATH = "/content/drive/MyDrive/EdgeAI/FreshSense/datasets/processed/banana"

# %%
# !ls /content/drive/MyDrive/EdgeAI/FreshSense/datasets/processed/banana
# Out:
# data.yaml  test  test.cache  train  train.cache  val.cache
